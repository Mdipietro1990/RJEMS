# %%
# imports
import numpy as np
import pandas as pd
import re
import time
from datasketch import MinHash, MinHashLSHForest

# %%
#Data Preprocessing and will split the data by punctuation 
def preprocess_text(text):
    text = re.sub(r'[^\w\s]','',text)
    tokens = text.lower()
    tokens = tokens.split()
    return tokens

# %%
text = 'The big brown fox jumped over the fence '
print('Shingles are:', preprocess_text(text))
# Out:
# ('Shingles are:', ['the', 'big', 'brown', 'fox', 'jumped', 'over', 'the', 'fence'])

# %%
#Standard number of combinations run
combo= 128

#Num recommendations to return from the data
num_rec = 1

# %%
def get_forest_info(data, perms):
    start_time = time.time()
    
    minhash = []
    
    for text in data['text']:
        tokens = preprocess(text)
        m = MinHash(num_perm=perms)
        for s in tokens:
            m.update(s.encode('utf8'))
        minhash.append(m)
        
    forest = MinHashLSHForest(num_perm=perms)
    
    for i,m in enumerate(minhash):
        forest.add(i,m)
        
    forest.index()
    
    print('It took %s seconds to build the forest.' %(time.time()-start_time))
    
    return forest

# %%
def prediction(text, database, perms, num_results, forest):
    start_time = time.time()
    
    tokens = preprocess(text)
    m = MinHash(num_perm=perms)
    for s in tokens:
        m.update(s.encode('utf8'))
        
    idx_array = np.array(forest.query(m, num_results))
    if len(idx_array) == 0:
        return None # if your query is empty, return none
    
    result = database.iloc[idx_array]['title']
    
    print('It took %s seconds to query the forest.' %(time.time()-start_time))
    
    return result

# %%
data= pd.read_csv('/Users/matt/Downloads/nips-papers/papers.csv')

# %%
data
# Out:
#         id  year                                              title  \
# 0        1  1987  Self-Organization of Associative Database and ...
# 1       10  1987  A Mean Field Theory of Layer IV of Visual Cort...
# 2      100  1988  Storing Covariance by the Associative Long-Ter...
# 3     1000  1994  Bayesian Query Construction for Neural Network...
# 4     1001  1994  Neural Network Ensembles, Cross Validation, an...
# 5     1002  1994  Using a neural net to instantiate a deformable...
# 6     1003  1994           Plasticity-Mediated Competitive Learning
# 7     1004  1994  ICEG Morphology Classification using an Analog...
# 8     1005  1994  Real-Time Control of a Tokamak Plasma Using Ne...
# 9     1006  1994  Pulsestream Synapses with Non-Volatile Analogu...
# 10    1007  1994                 Learning to Play the Game of Chess
# 11    1008  1994       Multidimensional Scaling and Data Clustering
# 12    1009  1994  An experimental comparison of recurrent neural...
# 13     101  1988  Training Multilayer Perceptrons with the Exten...
# 14    1010  1994  Interference in Learning Internal Models of In...
# 15    1011  1994            Active Learning with Statistical Models
# 16    1012  1994  A Rapid Graph-based Method for Arbitrary Trans...
# 17    1013  1994  Ocular Dominance and Patterned Lateral Connect...
# 18    1014  1994  Associative Decorrelation Dynamics: A Theory o...
# 19    1015  1994  A Connectionist Technique for Accelerated Text...
# 20    1016  1994  Connectionist Speaker Normalization with Gener...
# 21    1017  1994  A Critical Comparison of Models for Orientatio...
# 22    1018  1994  Generalization in Reinforcement Learning: Safe...
# 23    1019  1994  A Mixture Model System for Medical and Machine...
# 24     102  1988  An Application of the Principle of Maximum Inf...
# 25    1020  1994  A Computational Model of Prefrontal Cortex Fun...
# 26    1021  1995       The Gamma MLP for Speech Phoneme Recognition
# 27    1022  1995  A Multiscale Attentional Framework for Relaxat...
# 28    1023  1995  Correlated Neuronal Response: Time Scales and ...
# 29    1024  1995                     Onset-based Sound Segmentation
# ...    ...   ...                                                ...
# 7211   971  1994  Combining Estimators Using Non-Constant Weight...
# 7212   972  1994  A model of the hippocampus combining self-orga...
# 7213   973  1994  Catastrophic Interference in Human Motor Learning
# 7214   974  1994  Model of a Biological Neuron as a Temporal Neu...
# 7215   975  1994                            Dynamic Cell Structures
# 7216   976  1994                    On-line Learning of Dichotomies
# 7217   977  1994  New Algorithms for 2D and 3D Point Matching: P...
# 7218   978  1994                        Pattern Playback in the 90s
# 7219   979  1994  Learning in large linear perceptrons and why t...
# 7220    98  1988  Spreading Activation over Distributed Microfea...
# 7221   980  1994  Interior Point Implementations of Alternating ...
# 7222   981  1994  Reinforcement Learning with Soft State Aggrega...
# 7223   982  1994  Coarse-to-Fine Image Search Using Neural Networks
# 7224   983  1994      On the Computational Utility of Consciousness
# 7225   984  1994        A Convolutional Neural Network Hand Tracker
# 7226   985  1994  Efficient Methods for Dealing with Missing Dat...
# 7227   986  1994      Grammar Learning by a Self-Organizing Network
# 7228   987  1994  Recurrent Networks: Second Order Properties an...
# 7229   988  1994  Comparing the prediction accuracy of artificia...
# 7230   989  1994   Convergence Properties of the K-Means Algorithms
# 7231    99  1988  Analog Implementation of Shunting Neural Networks
# 7232   990  1994                        Learning with Product Units
# 7233   991  1994  Stochastic Dynamics of Three-State Neural Netw...
# 7234   992  1994  Grouping Components of Three-Dimensional Movin...
# 7235   993  1994  Visual Speech Recognition with Stochastic Netw...
# 7236   994  1994                Single Transistor Learning Synapses
# 7237   996  1994  Bias, Variance and the Combination of Least Sq...
# 7238   997  1994          A Real Time Clustering CMOS Neural Engine
# 7239   998  1994  Learning direction in global motion: two class...
# 7240   999  1994  Correlation and Interpolation Networks for Rea...
#
#      event_type                                           pdf_name  \
# 0           NaN  1-self-organization-of-associative-database-an...
# 1           NaN  10-a-mean-field-theory-of-layer-iv-of-visual-c...
# 2           NaN  100-storing-covariance-by-the-associative-long...
# 3           NaN  1000-bayesian-query-construction-for-neural-ne...
# 4           NaN  1001-neural-network-ensembles-cross-validation...
# 5           NaN  1002-using-a-neural-net-to-instantiate-a-defor...
# 6           NaN  1003-plasticity-mediated-competitive-learning.pdf
# 7           NaN  1004-iceg-morphology-classification-using-an-a...
# 8           NaN  1005-real-time-control-of-a-tokamak-plasma-usi...
# 9           NaN  1006-pulsestream-synapses-with-non-volatile-an...
# 10          NaN        1007-learning-to-play-the-game-of-chess.pdf
# 11          NaN  1008-multidimensional-scaling-and-data-cluster...
# 12          NaN  1009-an-experimental-comparison-of-recurrent-n...
# 13          NaN  101-training-multilayer-perceptrons-with-the-e...
# 14          NaN  1010-interference-in-learning-internal-models-...
# 15          NaN   1011-active-learning-with-statistical-models.pdf
# 16          NaN  1012-a-rapid-graph-based-method-for-arbitrary-...
# 17          NaN  1013-ocular-dominance-and-patterned-lateral-co...
# 18          NaN  1014-associative-decorrelation-dynamics-a-theo...
# 19          NaN  1015-a-connectionist-technique-for-accelerated...
# 20          NaN  1016-connectionist-speaker-normalization-with-...
# 21          NaN  1017-a-critical-comparison-of-models-for-orien...
# 22          NaN  1018-generalization-in-reinforcement-learning-...
# 23          NaN  1019-a-mixture-model-system-for-medical-and-ma...
# 24          NaN  102-an-application-of-the-principle-of-maximum...
# 25          NaN  1020-a-computational-model-of-prefrontal-corte...
# 26          NaN  1021-the-gamma-mlp-for-speech-phoneme-recognit...
# 27          NaN  1022-a-multiscale-attentional-framework-for-re...
# 28          NaN  1023-correlated-neuronal-response-time-scales-...
# 29          NaN            1024-onset-based-sound-segmentation.pdf
# ...         ...                                                ...
# 7211        NaN  971-combining-estimators-using-non-constant-we...
# 7212        NaN  972-a-model-of-the-hippocampus-combining-self-...
# 7213        NaN  973-catastrophic-interference-in-human-motor-l...
# 7214        NaN  974-model-of-a-biological-neuron-as-a-temporal...
# 7215        NaN                    975-dynamic-cell-structures.pdf
# 7216        NaN            976-on-line-learning-of-dichotomies.pdf
# 7217        NaN  977-new-algorithms-for-2d-and-3d-point-matchin...
# 7218        NaN                978-pattern-playback-in-the-90s.pdf
# 7219        NaN  979-learning-in-large-linear-perceptrons-and-w...
# 7220        NaN  98-spreading-activation-over-distributed-micro...
# 7221        NaN  980-interior-point-implementations-of-alternat...
# 7222        NaN  981-reinforcement-learning-with-soft-state-agg...
# 7223        NaN  982-coarse-to-fine-image-search-using-neural-n...
# 7224        NaN  983-on-the-computational-utility-of-consciousn...
# 7225        NaN  984-a-convolutional-neural-network-hand-tracke...
# 7226        NaN  985-efficient-methods-for-dealing-with-missing...
# 7227        NaN  986-grammar-learning-by-a-self-organizing-netw...
# 7228        NaN  987-recurrent-networks-second-order-properties...
# 7229        NaN  988-comparing-the-prediction-accuracy-of-artif...
# 7230        NaN  989-convergence-properties-of-the-k-means-algo...
# 7231        NaN  99-analog-implementation-of-shunting-neural-ne...
# 7232        NaN                990-learning-with-product-units.pdf
# 7233        NaN  991-stochastic-dynamics-of-three-state-neural-...
# 7234        NaN  992-grouping-components-of-three-dimensional-m...
# 7235        NaN  993-visual-speech-recognition-with-stochastic-...
# 7236        NaN        994-single-transistor-learning-synapses.pdf
# 7237        NaN  996-bias-variance-and-the-combination-of-least...
# 7238        NaN  997-a-real-time-clustering-cmos-neural-engine.pdf
# 7239        NaN  998-learning-direction-in-global-motion-two-cl...
# 7240        NaN  999-correlation-and-interpolation-networks-for...
#
#               abstract                                         paper_text
# 0     Abstract Missing  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1     Abstract Missing  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2     Abstract Missing  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3     Abstract Missing  Bayesian Query Construction for Neural\nNetwor...
# 4     Abstract Missing  Neural Network Ensembles, Cross\nValidation, a...
# 5     Abstract Missing  U sing a neural net to instantiate a\ndeformab...
# 6     Abstract Missing  Plasticity-Mediated Competitive Learning\n\nTe...
# 7     Abstract Missing  ICEG Morphology Classification using an\nAnalo...
# 8     Abstract Missing  Real-Time Control of a Tokamak Plasma\nUsing N...
# 9     Abstract Missing  Real-Time Control of a Tokamak Plasma\nUsing N...
# 10    Abstract Missing  Learning To Play the Game of Chess\n\nSebastia...
# 11    Abstract Missing  Multidimensional Scaling and Data Clustering\n...
# 12    Abstract Missing  An experimental comparison\nof recurrent neura...
# 13    Abstract Missing  133\n\nTRAINING MULTILAYER PERCEPTRONS WITH TH...
# 14    Abstract Missing  Interference in Learning Internal\nModels of I...
# 15    Abstract Missing  Active Learning with Statistical Models\n\nDav...
# 16    Abstract Missing  A Rapid Graph-based Method for\nArbitrary Tran...
# 17    Abstract Missing  Ocular Dominance and Patterned Lateral\nConnec...
# 18    Abstract Missing  Associative Decorrelation Dynamics:\nA Theory ...
# 19    Abstract Missing  A Connectionist Technique for Accelerated\nTex...
# 20    Abstract Missing  Connectionist Speaker Normalization\nwith Gene...
# 21    Abstract Missing  A Critical Comparison of Models for\nOrientati...
# 22    Abstract Missing  Generalization in Reinforcement Learning:\nSaf...
# 23    Abstract Missing  A Mixture Model System for Medical and\nMachin...
# 24    Abstract Missing  186\n\nAN APPLICATION OF THE PRINCIPLE OF\nMAX...
# 25    Abstract Missing  A Computational Model of Prefrontal\nCortex Fu...
# 26    Abstract Missing  The Gamma MLP for Speech Phoneme\nRecognition\...
# 27    Abstract Missing  A Multiscale Attentional Framework for\nRelaxa...
# 28    Abstract Missing  Correlated Neuronal Response:\nTime Scales and...
# 29    Abstract Missing  Onset-based Sound Segmentation\n\nLeslie S. Sm...
# ...                ...                                                ...
# 7211  Abstract Missing  Combining Estimators Using\nNon-Constant Weigh...
# 7212  Abstract Missing  A model of the hippocampus combining selforgan...
# 7213  Abstract Missing  Catastrophic Interference in Human\nMotor Lear...
# 7214  Abstract Missing  Model of a Biological Neuron as a Temporal\nNe...
# 7215  Abstract Missing  Dynamic Cell Structures\nJorg Bruske and Geral...
# 7216  Abstract Missing  On-line Learning of Dichotomies\n\nN. Barkai\n...
# 7217  Abstract Missing  New Algorithms for\n2D and 3D Point Matching:\...
# 7218  Abstract Missing  Pattern Playback in the '90s\nMalcolm Slaney\n...
# 7219  Abstract Missing  Learning in large linear perceptrons and\nwhy ...
# 7220  Abstract Missing  553\n\nSPREADING ACTIVATION OVER\nDISTRIBUTED ...
# 7221  Abstract Missing  Interior Point Implementations of\nAlternating...
# 7222  Abstract Missing  Reinforcement Learning with Soft State\nAggreg...
# 7223  Abstract Missing  Coarse-to-Fine Image Search Using Neural\nNetw...
# 7224  Abstract Missing  On the Computational Utility of\nConsciousness...
# 7225  Abstract Missing  A Convolutional Neural Network\nHand Tracker\n...
# 7226  Abstract Missing  Efficient Methods for Dealing with\nMissing Da...
# 7227  Abstract Missing  Grammar Learning by a Self-Organizing\nNetwork...
# 7228  Abstract Missing  Recurrent Networks:\nSecond Order Properties a...
# 7229  Abstract Missing  Comparing the prediction accuracy of\nartifici...
# 7230  Abstract Missing  Convergence Properties of the K-Means\nAlgorit...
# 7231  Abstract Missing  695\n\nANALOG IMPLEMENTATION OF SHUNTING\nNEUR...
# 7232  Abstract Missing  Comparing the prediction accuracy of\nartifici...
# 7233  Abstract Missing  Stochastic Dynamics of Three-State\nNeural Net...
# 7234  Abstract Missing  Grouping Components of\n?\nThree-Dimensional M...
# 7235  Abstract Missing  Visual Speech Recognition with\nStochastic Net...
# 7236  Abstract Missing  Single Transistor Learning Synapses\n\nPaul Ha...
# 7237  Abstract Missing  Bias, Variance and the Combination of\nLeast S...
# 7238  Abstract Missing  A Real Time Clustering CMOS\nNeural Engine\nT....
# 7239  Abstract Missing  Learning direction in global motion: two\nclas...
# 7240  Abstract Missing  Correlation and Interpolation Networks for\nRe...
#
# [7241 rows x 7 columns]

# %%
len(data)
# Out:
# 7241

# %%
len(data.abstract=='Abstract Missing')
# Out:
# 7241

# %%
len(data.abstract.unique())
# Out:
# 3923

# %%
data['text'] = data['title'] + ' ' + data['abstract']

# %%
data['text']
# Out:
# 0       Self-Organization of Associative Database and ...
# 1       A Mean Field Theory of Layer IV of Visual Cort...
# 2       Storing Covariance by the Associative Long-Ter...
# 3       Bayesian Query Construction for Neural Network...
# 4       Neural Network Ensembles, Cross Validation, an...
# 5       Using a neural net to instantiate a deformable...
# 6       Plasticity-Mediated Competitive Learning Abstr...
# 7       ICEG Morphology Classification using an Analog...
# 8       Real-Time Control of a Tokamak Plasma Using Ne...
# 9       Pulsestream Synapses with Non-Volatile Analogu...
# 10      Learning to Play the Game of Chess Abstract Mi...
# 11      Multidimensional Scaling and Data Clustering A...
# 12      An experimental comparison of recurrent neural...
# 13      Training Multilayer Perceptrons with the Exten...
# 14      Interference in Learning Internal Models of In...
# 15      Active Learning with Statistical Models Abstra...
# 16      A Rapid Graph-based Method for Arbitrary Trans...
# 17      Ocular Dominance and Patterned Lateral Connect...
# 18      Associative Decorrelation Dynamics: A Theory o...
# 19      A Connectionist Technique for Accelerated Text...
# 20      Connectionist Speaker Normalization with Gener...
# 21      A Critical Comparison of Models for Orientatio...
# 22      Generalization in Reinforcement Learning: Safe...
# 23      A Mixture Model System for Medical and Machine...
# 24      An Application of the Principle of Maximum Inf...
# 25      A Computational Model of Prefrontal Cortex Fun...
# 26      The Gamma MLP for Speech Phoneme Recognition A...
# 27      A Multiscale Attentional Framework for Relaxat...
# 28      Correlated Neuronal Response: Time Scales and ...
# 29        Onset-based Sound Segmentation Abstract Missing
#                               ...
# 7211    Combining Estimators Using Non-Constant Weight...
# 7212    A model of the hippocampus combining self-orga...
# 7213    Catastrophic Interference in Human Motor Learn...
# 7214    Model of a Biological Neuron as a Temporal Neu...
# 7215             Dynamic Cell Structures Abstract Missing
# 7216     On-line Learning of Dichotomies Abstract Missing
# 7217    New Algorithms for 2D and 3D Point Matching: P...
# 7218         Pattern Playback in the 90s Abstract Missing
# 7219    Learning in large linear perceptrons and why t...
# 7220    Spreading Activation over Distributed Microfea...
# 7221    Interior Point Implementations of Alternating ...
# 7222    Reinforcement Learning with Soft State Aggrega...
# 7223    Coarse-to-Fine Image Search Using Neural Netwo...
# 7224    On the Computational Utility of Consciousness ...
# 7225    A Convolutional Neural Network Hand Tracker Ab...
# 7226    Efficient Methods for Dealing with Missing Dat...
# 7227    Grammar Learning by a Self-Organizing Network ...
# 7228    Recurrent Networks: Second Order Properties an...
# 7229    Comparing the prediction accuracy of artificia...
# 7230    Convergence Properties of the K-Means Algorith...
# 7231    Analog Implementation of Shunting Neural Netwo...
# 7232         Learning with Product Units Abstract Missing
# 7233    Stochastic Dynamics of Three-State Neural Netw...
# 7234    Grouping Components of Three-Dimensional Movin...
# 7235    Visual Speech Recognition with Stochastic Netw...
# 7236    Single Transistor Learning Synapses Abstract M...
# 7237    Bias, Variance and the Combination of Least Sq...
# 7238    A Real Time Clustering CMOS Neural Engine Abst...
# 7239    Learning direction in global motion: two class...
# 7240    Correlation and Interpolation Networks for Rea...
# Name: text, Length: 7241, dtype: object

# %%
forest = get_forest_info(data, combo)
# Out:
# It took 23.0864419937 seconds to build the forest.

# %%
num_rec = 1
title = 'Using a neural net'
result = predict(title, data, combo, num_rec, forest)
print 'Top {} Recommendation(s) from nueral net are:\n{}'.format(num_rec,result)
print 'The number of results returned are {}'.format(len(result))
# Out:
# It took 0.00334405899048 seconds to query forest.
# Top 1 Recommendation(s) from nueral net are:
# 7085    Classification of Electroencephalogram using A...
# Name: title, dtype: object
# The number of results returned are 1

# %%
num_rec = 4
title = 'Using a neural net'
result = predict(title, data, combo, num_rec, forest)
print 'Top {} Recommendation(s) from nueral net are:\n{}'.format(num_rec,result)
print 'The number of results returned are {}'.format(len(result))
# Out:
# It took 0.0029821395874 seconds to query forest.
# Top 4 Recommendation(s) from nueral net are:
# 1051    Speech Recognition with Missing Data using Rec...
# 6987    Neural Network Exploration Using Optimal Exper...
# 7085    Classification of Electroencephalogram using A...
# 5047    Multi-Digit Recognition Using a Space Displace...
# Name: title, dtype: object
# The number of results returned are 4

# %%
num_rec = 10
title = 'Using a neural net'
result = predict(title, data, combo, num_rec, forest)
print 'Top {} Recommendation(s) from nueral net are:\n{}'.format(num_rec,result)
print 'The number of results returned are {}'.format(len(result))
# Out:
# It took 0.00451707839966 seconds to query forest.
# Top 10 Recommendation(s) from nueral net are:
# 5       Using a neural net to instantiate a deformable...
# 5191    A Self-Organizing Integrated Segmentation and ...
# 6987    Neural Network Exploration Using Optimal Exper...
# 2092    Combining Visual and Acoustic Speech Signals w...
# 7085    Classification of Electroencephalogram using A...
# 2868    Speech Recognition Using Demi-Syllable Neural ...
# 2069    Analytic Solutions to the Formation of Feature...
# 5047    Multi-Digit Recognition Using a Space Displace...
# 1305    Optoelectronic Implementation of a FitzHugh-Na...
# 1051    Speech Recognition with Missing Data using Rec...
# Name: title, dtype: object
# The number of results returned are 10

# %%
combo = 512

# %%
num_rec = 10
title = 'Using a neural net'
result = predict(title, data, combo, num_rec, forest)
print 'Top {} Recommendation(s) from nueral net are:\n{}'.format(num_rec,result)
print 'The number of results returned are {}'.format(len(result))
# Out:
# It took 0.00538396835327 seconds to query forest.
# Top 10 Recommendation(s) from nueral net are:
# 5       Using a neural net to instantiate a deformable...
# 5191    A Self-Organizing Integrated Segmentation and ...
# 6987    Neural Network Exploration Using Optimal Exper...
# 2092    Combining Visual and Acoustic Speech Signals w...
# 7085    Classification of Electroencephalogram using A...
# 2868    Speech Recognition Using Demi-Syllable Neural ...
# 2069    Analytic Solutions to the Formation of Feature...
# 5047    Multi-Digit Recognition Using a Space Displace...
# 1305    Optoelectronic Implementation of a FitzHugh-Na...
# 1051    Speech Recognition with Missing Data using Rec...
# Name: title, dtype: object
# The number of results returned are 10
